# %%
import os
import pandas as pd
import io

# %%
#print le name sans le .sql
theme = []
for filename in os.listdir("answers"):
    if filename.endswith(".sql"):
        theme.append(filename[:-4])
print(sorted(theme))
# Out:
# ['appartements_gb1', 'appartements_gb2', 'beverages_and_food', 'beverages_and_food_sum', 'capteur_gb1', 'capteur_gb2', 'capteur_wf1', 'capteur_wf2', 'capteur_wf3', 'capteur_wf4', 'capteur_wf5', 'capteur_wf6', 'football_case_when', 'football_cte1', 'football_cte4', 'football_cte5', 'football_gb_cte2', 'football_gb_cte3', 'furniture_wf1', 'retail_case_when1', 'retail_case_when2', 'retail_group_by1', 'retail_group_by2', 'retail_group_by3', 'retail_group_by4', 'retail_group_by5', 'salaire_wf1', 'size_and_trademark', 'ventes_cte_join5', 'ventes_group_by', 'ventes_join1', 'ventes_join2', 'ventes_join3', 'ventes_join4', 'ventes_join_gb3', 'ventes_join_gb6']

# %%
clients = ["Oussama", "Julie", "Chris", "Tom"]
ventes = [120, 49, 35, 23, 19, 5.99, 20, 18.77, 39, 10, 17, 12]
ventes = pd.DataFrame(ventes)
ventes.columns = ["montant"]
ventes["client"] = clients * 3

# %%
ventes.to_csv("data/ventes.csv", index=False)

# %%
size = """
size
XS
S
M
L
XL
"""

trademark = """
trademark
Nike
Asphalte
Abercrombie
Lewis
"""

size = pd.read_csv(io.StringIO(size))
size.to_csv("data/size.csv", index=False)
trademark = pd.read_csv(io.StringIO(trademark))
trademark.to_csv("data/trademark.csv", index=False)

# %%
beverages = """
beverage,price
Orange juice,2.5
Expresso,2
Tea,3
Cappuccino,1.6
"""

food_items = """
food_item,price
Cookie juice,2.5
Chocolatine,2
Muffin,3
Croissant,1.6
"""

beverages = pd.read_csv(io.StringIO(beverages))
beverages.to_csv('data/beverages.csv',index=False)
food_items = pd.read_csv(io.StringIO(food_items))
food_items.to_csv('data/food_items.csv', index = False)

# %%
furniture_data = [
    ("Chairs", "Chair 1", 5.2),
    ("Chairs", "Chair 2", 4.5),
    ("Chairs", "Chair 3", 6.8),
    ("Sofas", "Sofa 1", 25.5),
    ("Sofas", "Sofa 2", 20.3),
    ("Sofas", "Sofa 3", 30.0),
    ("Tables", "Table 1", 15.0),
    ("Tables", "Table 2", 12.5),
    ("Tables", "Table 3", 18.2),
]

# Create a pandas DataFrame from the predefined data
furniture = pd.DataFrame(furniture_data, columns=["category", "item", "weight"])
furniture.to_csv('data/furniture.csv',index = False)

# %%
appartement = pd.read_csv('data/appartements.csv')
appartement
# Out:
#       Date mutation  valeur_fonciere  No voie Type de voie Code voie  \
# 0        04/01/2022         208000.0     64.0          RUE      0010
# 1        04/01/2022         113000.0      1.0          RUE      0260
# 2        03/01/2022         185000.0     22.0          RUE      8749
# 3        04/01/2022         120350.0    132.0          RUE      7554
# 4        04/01/2022         149000.0      7.0          ALL      3430
# ...             ...              ...      ...          ...       ...
# 20659    18/02/2022         400000.0      8.0          RUE      1540
# 20660    18/02/2022         400000.0      8.0          RUE      1540
# 20661    18/02/2022         400000.0      8.0          RUE      1540
# 20662    18/02/2022         400000.0      8.0          RUE      1540
# 20663    18/02/2022         400000.0      8.0          RUE      1540
#
#                     Voie  Code postal            Commune  Code departement  \
# ...

# %%
appartement.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20664 entries, 0 to 20663
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date mutation              20664 non-null  object
#  1   valeur_fonciere            20664 non-null  float64
#  2   No voie                    20346 non-null  float64
#  3   Type de voie               20370 non-null  object
#  4   Code voie                  20664 non-null  object
#  5   Voie                       20664 non-null  object
#  6   Code postal                20664 non-null  float64
#  7   Commune                    20664 non-null  object
#  8   Code departement           20664 non-null  int64
#  9   Code commune               20664 non-null  int64
#  10  Surface_Carrez_du_1er_lot  5649 non-null   object
#  11  Nombre pieces principales  20663 non-null  float64
#  12  Surface terrain            8129 non-null   float64
# ...

# %%
appartement['Surface_Carrez_du_1er_lot'] = appartement['Surface_Carrez_du_1er_lot'].str.replace(',', '.').astype(float)

# %%
appartement
# Out:
#       Date mutation  valeur_fonciere  No voie Type de voie Code voie  \
# 0        04/01/2022         208000.0     64.0          RUE      0010
# 1        04/01/2022         113000.0      1.0          RUE      0260
# 2        03/01/2022         185000.0     22.0          RUE      8749
# 3        04/01/2022         120350.0    132.0          RUE      7554
# 4        04/01/2022         149000.0      7.0          ALL      3430
# ...             ...              ...      ...          ...       ...
# 20659    18/02/2022         400000.0      8.0          RUE      1540
# 20660    18/02/2022         400000.0      8.0          RUE      1540
# 20661    18/02/2022         400000.0      8.0          RUE      1540
# 20662    18/02/2022         400000.0      8.0          RUE      1540
# 20663    18/02/2022         400000.0      8.0          RUE      1540
#
#                     Voie  Code postal            Commune  Code departement  \
# ...

# %%
appart_columns = appartement.columns.str.replace(' ', '_')
appart_columns
# Out:
# Index(['Date_mutation', 'valeur_fonciere', 'No_voie', 'Type_de_voie',
#        'Code_voie', 'Voie', 'Code_postal', 'Commune', 'Code_departement',
#        'Code_commune', 'Surface_Carrez_du_1er_lot',
#        'Nombre_pieces_principales', 'Surface_terrain'],
#       dtype='object')

# %%
appart_columns
# Out:
# Index(['Date mutation', 'valeur_fonciere', 'No voie', 'Type de voie',
#        'Code voie', 'Voie', 'Code postal', 'Commune', 'Code departement',
#        'Code commune', 'Surface_Carrez_du_1er_lot',
#        'Nombre pieces principales', 'Surface terrain'],
#       dtype='object')

# %%
appartement = appartement.rename(columns=lambda x: x.replace(' ', '_'))

# %%
appartement.to_csv('data/appartements.csv', index=False)

# %%
football = pd.read_csv("data/football.csv")
football
# Out:
#     Div      Date      HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    F1  07/08/10       Auxerre       Lorient     2     2   D     1     1   D
# 1    F1  07/08/10          Lens         Nancy     1     2   A     0     1   A
# 2    F1  07/08/10          Lyon        Monaco     0     0   D     0     0   D
# 3    F1  07/08/10     Marseille          Caen     1     2   A     0     0   D
# 4    F1  07/08/10          Nice  Valenciennes     0     0   D     0     0   D
# ..   ..       ...           ...           ...   ...   ...  ..   ...   ...  ..
# 375  F1  29/05/11       Lorient       Auxerre     1     2   A     1     1   D
# 376  F1  29/05/11        Monaco          Lyon     0     2   A     0     0   D
# 377  F1  29/05/11         Nancy          Lens     4     0   H     2     0   H
# 378  F1  29/05/11    St Etienne      Paris SG     1     1   D     0     0   D
# 379  F1  29/05/11  Valenciennes          Nice     2     1   H     0     0   D
#
# ...

# %%
(football[['Date','HomeTeam','AwayTeam','FTHG','FTAG']]
.rename(columns={'FTHG':'GoalsHomeTeam','FTAG':'GoalsAwayTeam'})
.to_csv('data/football.csv',index=False)
)
